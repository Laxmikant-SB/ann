# %%
import tensorflow as tf

from tensorflow.keras.datasets import mnist

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense, Flatten

from tensorflow.keras.optimizers import Adam

# =========================
# Load MNIST Dataset
# =========================

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize pixel values
X_train = X_train / 255.0

X_test = X_test / 255.0

# =========================
# Define Model Architecture
# =========================

model = Sequential([

    Flatten(input_shape=(28, 28)),

    Dense(
        128,
        activation='relu'
    ),

    Dense(
        10,
        activation='softmax'
    )
])

# =========================
# Compile Model
# =========================

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# =========================
# Train Model
# =========================

model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=10,
    verbose=1
)

# =========================
# Evaluate Model
# =========================

loss, accuracy = model.evaluate(
    X_test,
    y_test
)

# =========================
# Print Results
# =========================

print(f"Test Loss: {loss}")

print(f"Test Accuracy: {accuracy}")
# Out:
# C:\Users\LAXMIKANT\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8613 - loss: 0.5048
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9587 - loss: 0.1417
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9710 - loss: 0.0996
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9796 - loss: 0.0696
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9842 - loss: 0.0541
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9872 - loss: 0.0430
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9895 - loss: 0.0354
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0277
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0236
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9949 - loss: 0.0190
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9762 - loss: 0.0802
# Test Loss: 0.06871111690998077
# Test Accuracy: 0.9793000221252441
